# %% [markdown]
# # 7. Human Face Anatomy (Eyes, Nose, Lips Structure)

# %% [markdown]
# ![Screenshot from 2025-10-25 09-42-26.png](attachment:202d5ce1-0692-4c93-8c11-17b3b9834138.png)

# %% [markdown]
# ![Screenshot from 2025-10-25 09-43-04.png](attachment:e8010573-dc90-4180-b5af-4443efc72cdc.png)

# %% [markdown]
# ![Screenshot from 2025-10-25 09-43-37.png](attachment:2c8561c3-ceeb-4ed1-9f39-98f3775d4583.png)

# %% [markdown]
# ![Screenshot from 2025-10-25 09-44-15.png](attachment:94915424-aaeb-4e21-941a-97d33884254d.png)

# %% [markdown]
# ![Screenshot from 2025-10-25 09-44-46.png](attachment:1a32d3a7-7333-4e47-8cfb-524919409241.png)

# %%
import cv2
import dlib

# %%
# Load image
image_path = "../dataset/test/bellingham.jpg"
image = cv2.imread(image_path)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
# Load face detector and landmark predictor
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor("shape_predictor_68_face_landmarks.dat")  # Dlib pre-trained model

# %%
# Detect faces
faces = detector(gray)

for face in faces:
    # Draw rectangle around face
    x, y, w, h = face.left(), face.top(), face.width(), face.height()
    cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)
    
    # Detect landmarks
    landmarks = predictor(gray, face)
    
    # Draw landmarks
    for n in range(0, 68):
        x_point = landmarks.part(n).x
        y_point = landmarks.part(n).y
        cv2.circle(image, (x_point, y_point), 2, (0, 0, 255), -1)

# %%
# Show image
cv2.imshow("Face Landmarks", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![Screenshot from 2025-10-25 09-48-17.png](attachment:381b5613-d5c3-4deb-bd72-de164660c0a0.png)

# %% [markdown]
# ![Screenshot from 2025-10-25 09-48-54.png](attachment:d4a97c6a-492a-40b0-894c-dbaa2ab3fef2.png)

# %% [markdown]
# # 8. RGB, HSV, LAB Color Space ধারণা

# %% [markdown]
# ![Screenshot from 2025-10-25 09-50-52.png](attachment:4169e3c6-038d-4e61-8f7e-923d81eb41b7.png)

# %% [markdown]
# ![Screenshot from 2025-10-25 09-51-24.png](attachment:7e459068-22a0-4c8c-a13e-81fd0f1af360.png)

# %% [markdown]
# ![Screenshot from 2025-10-25 09-51-50.png](attachment:1fb08721-2b1b-4739-b699-9eb42e00497a.png)

# %% [markdown]
# ![Screenshot from 2025-10-25 09-52-23.png](attachment:c056428b-bd45-4f5c-b818-3ad9c1a8614c.png)

# %% [markdown]
# ![Screenshot from 2025-10-25 09-52-57.png](attachment:ca4a31a9-8b0e-453c-b5d8-718f7a286dbe.png)

# %%
import cv2
import matplotlib.pyplot as plt

# %%
# Load image
image = cv2.imread("../dataset/test/bellingham.jpg")
# OpenCV লোড করলে default BGR, তাই RGB এ convert
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
# Convert to HSV
image_hsv = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2HSV)

# %%
# Convert to LAB
image_lab = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2LAB)

# %%
# Plot Original & Color Spaces
fig, axes = plt.subplots(1, 4, figsize=(20, 5))

axes[0].imshow(image_rgb)
axes[0].set_title("Original RGB")
axes[0].axis('off')

axes[1].imshow(image_hsv)
axes[1].set_title("HSV")
axes[1].axis('off')

axes[2].imshow(image_lab)
axes[2].set_title("LAB")
axes[2].axis('off')

# Optionally show separate channels of RGB
r, g, b = cv2.split(image_rgb)
axes[3].imshow(r, cmap='Reds')
axes[3].set_title("Red Channel")
axes[3].axis('off')

plt.show()

# %% [markdown]
# ![Screenshot from 2025-10-25 09-55-55.png](attachment:56a77a65-7baf-4b3b-b743-137a8115dca4.png)

# %% [markdown]
# # 9. Image Pixel, Matrix & Channels (1D, 2D, 3D Array)

# %% [markdown]
# ![Screenshot from 2025-10-25 09-59-01.png](attachment:a09abd5a-66dd-4b06-b045-bfee1d323bf6.png)

# %% [markdown]
# ![Screenshot from 2025-10-25 09-59-32.png](attachment:afda127e-e1f1-4bc6-8cbb-26a89570d7c1.png)

# %% [markdown]
# ![Screenshot from 2025-10-25 10-00-10.png](attachment:4ed8386f-cb7a-4f3f-8a94-95acd26faae4.png)

# %% [markdown]
# ![Screenshot from 2025-10-25 10-00-37.png](attachment:1a9674bd-afa9-4119-bc16-ab4485c78ab1.png)

# %% [markdown]
# ![Screenshot from 2025-10-25 10-01-10.png](attachment:567ec45b-b59c-4b4d-8316-e6ba048b2b00.png)

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# Load Image
image = cv2.imread("../dataset/test/bellingham.jpg")        # OpenCV loads BGR
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)


# Convert to Grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)


# Print Shapes
print("RGB Image Shape:", image_rgb.shape)   # (height, width, 3)
print("Grayscale Image Shape:", gray.shape)  # (height, width)


# Split RGB Channels
R, G, B = cv2.split(image_rgb)
print("R Channel shape:", R.shape)
print("G Channel shape:", G.shape)
print("B Channel shape:", B.shape)


# Visualize Images and Channels
fig, axes = plt.subplots(2,3, figsize=(15,8))

axes[0,0].imshow(image_rgb)
axes[0,0].set_title("Original RGB")
axes[0,0].axis('off')

axes[0,1].imshow(gray, cmap='gray')
axes[0,1].set_title("Grayscale")
axes[0,1].axis('off')

axes[0,2].imshow(R, cmap='Reds')
axes[0,2].set_title("Red Channel")
axes[0,2].axis('off')

axes[1,0].imshow(G, cmap='Greens')
axes[1,0].set_title("Green Channel")
axes[1,0].axis('off')

axes[1,1].imshow(B, cmap='Blues')
axes[1,1].set_title("Blue Channel")
axes[1,1].axis('off')

# Optional: Combine channels back to RGB
merged = cv2.merge([R, G, B])
axes[1,2].imshow(merged)
axes[1,2].set_title("Merged RGB")
axes[1,2].axis('off')

plt.show()
# Out:
# RGB Image Shape: (324, 324, 3)
# Grayscale Image Shape: (324, 324)
# R Channel shape: (324, 324)
# G Channel shape: (324, 324)
# B Channel shape: (324, 324)

# %% [markdown]
# ![Screenshot from 2025-10-25 10-03-18.png](attachment:ab4f24d6-4b41-4fa4-9884-772afd9bdafd.png)

# %% [markdown]
# # 10. Grayscale Conversion

# %% [markdown]
# ![Screenshot from 2025-10-25 10-07-43.png](attachment:dcc8eb0a-0f08-4722-bd18-ad01e21b0cf1.png)

# %% [markdown]
# ![Screenshot from 2025-10-25 10-08-27.png](attachment:5fea7dc4-84e3-4352-9246-89ebe24f4446.png)

# %%
import cv2
import matplotlib.pyplot as plt

# Load color image
image = cv2.imread("../dataset/test/sinner.jpeg")  # OpenCV loads BGR
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Convert to Grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Display images
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(image_rgb)
plt.title("Original RGB")
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(gray, cmap='gray')
plt.title("Grayscale")
plt.axis('off')
plt.show()

# %% [markdown]
# ![Screenshot from 2025-10-25 10-09-33.png](attachment:9f0e95f3-b152-4a36-b83b-4d18cd24ac1b.png)

# %% [markdown]
# ![Screenshot from 2025-10-25 10-10-16.png](attachment:9ec5c477-01f2-4da5-aa55-cf586827d170.png)

# %%
import cv2
import matplotlib.pyplot as plt


# Load Image and Convert to Grayscale
image = cv2.imread("../dataset/test/sinner.jpeg")
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)


# Binary Thresholding
# Threshold value = 127, max_value = 255
_, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)


# Histogram of Grayscale Image
hist = cv2.calcHist([gray], [0], None, [256], [0,256])

# Visualization
plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.imshow(gray, cmap='gray')
plt.title("Grayscale Image")
plt.axis('off')

plt.subplot(1,3,2)
plt.imshow(binary, cmap='gray')
plt.title("Binary Thresholding")
plt.axis('off')

plt.subplot(1,3,3)
plt.plot(hist, color='black')
plt.title("Grayscale Histogram")
plt.xlim([0,256])

plt.show()

# %% [markdown]
# ![Screenshot from 2025-10-25 10-11-49.png](attachment:c8aa16c2-e8a9-4488-977a-54aac79f83cd.png)

# %% [markdown]
# # 11. Image Resolution, DPI, Aspect Ratio

# %% [markdown]
# ![Screenshot from 2025-10-25 10-31-53.png](attachment:3a54d60c-b728-406a-b5c4-5179efb6e3b4.png)

# %% [markdown]
# ![Screenshot from 2025-10-25 10-32-27.png](attachment:9399bff9-ebb2-49f4-999b-91066cb3cf7f.png)

# %% [markdown]
# ![Screenshot from 2025-10-25 10-32-59.png](attachment:6b12f5b8-b24f-414a-ab7b-0103bf747b39.png)

# %% [markdown]
# ![Screenshot from 2025-10-25 10-33-24.png](attachment:57215613-3a0e-435a-872b-e29db03dd56a.png)

# %% [markdown]
# ![Screenshot from 2025-10-25 10-34-00.png](attachment:fad35fc9-4817-4ae5-a2ea-27c2afb32b69.png)

# %%
import cv2

# Load Image
image = cv2.imread("../dataset/test/ronaldo.jpg")
height, width, channels = image.shape

print(f"Original Resolution: {width}x{height} pixels")
print(f"Channels: {channels}")


# Desired width (maintain aspect ratio)
desired_width = 300
aspect_ratio = width / height
new_height = int(desired_width / aspect_ratio)

# Resize image
resized_image = cv2.resize(image, (desired_width, new_height))

print(f"Resized Resolution: {resized_image.shape[1]}x{resized_image.shape[0]} pixels")


# Show images
cv2.imshow("Original Image", image)
cv2.imshow("Resized Image", resized_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Original Resolution: 300x390 pixels
# Channels: 3
# Resized Resolution: 300x390 pixels

# %% [markdown]
# ![Screenshot from 2025-10-25 10-35-44.png](attachment:1f68f790-4ef4-4466-bb52-10055a5d7591.png)

# %% [markdown]
# # 12. Image Scaling ও Resizing Concept

# %% [markdown]
# ![Screenshot from 2025-10-25 10-43-22.png](attachment:eccfe17f-dc52-4c69-bfd3-062d8d12c9c1.png)

# %% [markdown]
# ![Screenshot from 2025-10-25 10-43-56.png](attachment:0f0169cf-51eb-40c9-afd2-90c3122a7e7e.png)

# %% [markdown]
# ![Screenshot from 2025-10-25 10-44-26.png](attachment:d622140d-1990-4043-b4a7-b03627e1bbd8.png)

# %%
import cv2

# Load image
image = cv2.imread("../dataset/test/cummins.jpg")
height, width = image.shape[:2]
print("Original Resolution:", width, "x", height)

# 1. Scaling (factor 0.5)
scale_factor = 0.5
scaled_image = cv2.resize(image, (0,0), fx=scale_factor, fy=scale_factor)
print("Scaled Resolution:", scaled_image.shape[1], "x", scaled_image.shape[0])


# 2. Resizing (fixed size 256x256)
resized_image = cv2.resize(image, (256,256))
print("Resized Resolution:", resized_image.shape[1], "x", resized_image.shape[0])

# Display
cv2.imshow("Original", image)
cv2.imshow("Scaled", scaled_image)
cv2.imshow("Resized", resized_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Original Resolution: 587 x 629
# Scaled Resolution: 294 x 314
# Resized Resolution: 256 x 256

# %% [markdown]
# ![Screenshot from 2025-10-25 10-46-00.png](attachment:568d4d17-5053-4865-a765-fa8a9eb78e1c.png)

# %% [markdown]
# # 13. Image Resolution, Scaling, এবং Normalization

# %% [markdown]
# ![Screenshot from 2025-10-25 10-47-36.png](attachment:64763c64-4b07-472d-b350-49dadff03922.png)

# %% [markdown]
# ![Screenshot from 2025-10-25 10-48-16.png](attachment:c2cb153e-d361-4b04-957e-4694878943f0.png)

# %% [markdown]
# ![Screenshot from 2025-10-25 10-48-45.png](attachment:e97000d0-1755-46ce-ae4d-1064cf595b69.png)

# %%
import cv2
import numpy as np

# Load image
image = cv2.imread("../dataset/test/ronaldo.jpg")
height, width = image.shape[:2]
print("Original Resolution:", width, "x", height)

# Resize to fixed size (CNN input)
resized_image = cv2.resize(image, (128,128))
print("Resized Resolution:", resized_image.shape[1], "x", resized_image.shape[0])

# Normalize pixel values to 0-1
normalized_image = resized_image / 255.0
print("Pixel range after normalization:", normalized_image.min(), "-", normalized_image.max())
# Out:
# Original Resolution: 300 x 390
# Resized Resolution: 128 x 128
# Pixel range after normalization: 0.0 - 0.9921568627450981

# %% [markdown]
# ![Screenshot from 2025-10-25 10-49-22.png](attachment:5ea8570d-1459-4cd3-b534-c25d669d78dc.png)

# %% [markdown]
# # 14. Dataset, Labels ও Annotation ধারণা

# %% [markdown]
# ![Screenshot from 2025-10-25 10-51-44.png](attachment:1506e8b1-a92c-4bd3-ae78-ff03f2112b02.png)

# %% [markdown]
# ![Screenshot from 2025-10-25 10-52-11.png](attachment:205417d0-4654-4eea-84d2-5bf95bf6374d.png)

# %% [markdown]
# ![Screenshot from 2025-10-25 10-52-53.png](attachment:7b0d4ccb-2b24-4cc4-883b-d0ce935bccb0.png)

# %% [markdown]
# ![Screenshot from 2025-10-25 10-53-18.png](attachment:4c6d2130-7bd3-4937-9bef-adf61764dc55.png)

# %% [markdown]
# ![Screenshot from 2025-10-25 10-53-48.png](attachment:c38be2d2-2e5b-48da-acd1-3117738fd91d.png)

# %%
import cv2

# Load image
image = cv2.imread("../dataset/test/sinner.jpeg")

# Define annotation manually
annotation = {
    "bbox": [100, 50, 200, 200],  # x, y, width, height
    "landmarks": [
        [130, 90], [170, 90], [150, 130], [140, 170], [160, 170]  # eyes, nose, lips
    ]
}

# Draw bounding box
x, y, w, h = annotation["bbox"]
cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)

# Draw landmarks
for (lx, ly) in annotation["landmarks"]:
    cv2.circle(image, (lx, ly), 3, (0, 0, 255), -1)

# Show image
cv2.imshow("Annotated Face", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![Screenshot from 2025-10-25 10-57-47.png](attachment:d02ffea0-d42e-478d-83ec-eeaff69b691d.png)
