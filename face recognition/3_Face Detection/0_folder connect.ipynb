# %%
import os

train_dir = "../dataset/train"
total_folders = 0
total_images = 0

for label in os.listdir(train_dir):
    label_path = os.path.join(train_dir, label)
    if os.path.isdir(label_path):
        total_folders += 1
        images = [f for f in os.listdir(label_path) if os.path.isfile(os.path.join(label_path, f))]
        num_images = len(images)
        total_images += num_images
        print(f"Label: {label}, Total Images: {num_images}")
# Out:
# Label: trent, Total Images: 5
# Label: costa, Total Images: 4
# Label: fernandes, Total Images: 5
# Label: dias, Total Images: 6
# Label: kohli, Total Images: 5
# Label: cancelo, Total Images: 6
# Label: pickford, Total Images: 6
# Label: sinner, Total Images: 3
# Label: brozovic, Total Images: 5
# Label: vitinha, Total Images: 5
# Label: deligt, Total Images: 5
# Label: messi, Total Images: 6
# Label: bale, Total Images: 5
# Label: pepe, Total Images: 5
# Label: saka, Total Images: 4
# Label: marcelo, Total Images: 5
# Label: ozil, Total Images: 7
# Label: bruyne, Total Images: 6
# Label: casimiro, Total Images: 5
# Label: mbappe, Total Images: 6
# Label: ramos, Total Images: 6
# Label: rodriguez, Total Images: 5
# Label: shelton, Total Images: 3
# Label: ronaldo, Total Images: 6
# Label: mendes, Total Images: 5
# Label: mane, Total Images: 5
# Label: haaland, Total Images: 5
# Label: gordon, Total Images: 5
# Label: cummins, Total Images: 3
# Label: aqidi, Total Images: 5

# %%
print(f"\nTotal Folders/Labels: {total_folders}")
print(f"Total Images in Dataset: {total_images}")
# Out:
# Total Folders/Labels: 30
# Total Images in Dataset: 152

# %%
import os

train_dir = "../dataset/train"
labels = []

for label in os.listdir(train_dir):
    label_path = os.path.join(train_dir, label)
    if os.path.isdir(label_path):
        labels.append(label)

# Alphabetical sort
labels.sort()

print("Labels:", labels)
# Out:
# Labels: ['aqidi', 'bale', 'brozovic', 'bruyne', 'cancelo', 'casimiro', 'costa', 'cummins', 'deligt', 'dias', 'fernandes', 'gordon', 'haaland', 'kohli', 'mane', 'marcelo', 'mbappe', 'mendes', 'messi', 'ozil', 'pepe', 'pickford', 'ramos', 'rodriguez', 'ronaldo', 'saka', 'shelton', 'sinner', 'trent', 'vitinha']
