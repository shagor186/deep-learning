# %% [markdown]
# # 1. Basic

# %% [markdown]
# ![Screenshot from 2025-10-25 16-36-50.png](attachment:9441327f-0b03-4e70-ba9b-9013d1247ee3.png)

# %% [markdown]
# ![Screenshot from 2025-10-25 16-37-39.png](attachment:1af4aa56-a8f4-4a68-876b-e2d39c9b5907.png)

# %% [markdown]
# ![Screenshot from 2025-10-25 16-38-26.png](attachment:aa418b96-c4fa-4fdf-87a9-d65619ab844e.png)

# %% [markdown]
# ![Screenshot from 2025-10-25 16-38-55.png](attachment:d141ca7a-bf4f-4b7d-b9a8-848d79c3c85f.png)

# %% [markdown]
# ## 1. Individual Image Detection

# %%
import cv2

# Haar Cascade লোড
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# ইমেজ লোড
img = cv2.imread('../dataset/test/bellingham.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# মুখ সনাক্তকরণ
faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)

# detected faces draw
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)

cv2.imshow('Face Detection - Image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![Screenshot from 2025-10-25 16-41-07.png](attachment:3ea55e48-4262-4aa2-a2d2-77d06ef6a8cb.png)

# %% [markdown]
# ## 2. Video File Detection

# %%
import cv2

# Haar Cascade লোড
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# ভিডিও লোড
cap = cv2.VideoCapture('../dataset/vid/s.mp4')

while True:
    ret, frame = cap.read()
    if not ret:
        break

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.1, 5)

    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)

    cv2.imshow('Face Detection - Video', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ![Screenshot from 2025-10-25 16-42-59.png](attachment:ae138907-beeb-49dc-8847-8bd4d8c967dd.png)

# %% [markdown]
# ## 3. Webcam Detection (Real-Time)

# %%
import cv2

# Haar Cascade লোড
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Webcam Capture
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.1, 5)

    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)

    cv2.imshow('Face Detection - Webcam', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ![Screenshot from 2025-10-25 16-44-30.png](attachment:da539cd6-5a1d-4093-b51b-13aff49c95ee.png)

# %% [markdown]
# # 2. Tips

# %% [markdown]
# ![Screenshot from 2025-10-25 16-46-22.png](attachment:4dc60c64-f4ae-4a94-aac8-31430e1a2a56.png)

# %% [markdown]
# ![Screenshot from 2025-10-25 16-47-01.png](attachment:d4f4a71d-3808-4bad-abf7-133e9bad93b5.png)

# %% [markdown]
# ## 1. Individual Image Detection¶

# %%
import cv2

# 1️⃣ Haar Cascade লোড করা
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# 2️⃣ ইমেজ লোড করা
img_path = "../dataset/test/bellingham.jpg"   # 👉 আপনার ইমেজ পাথ দিন
img = cv2.imread(img_path)

# 3️⃣ ইমেজকে গ্রেস্কেলে রূপান্তর
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# 4️⃣ মুখ সনাক্তকরণ (parameter সহ)
faces = face_cascade.detectMultiScale(
    gray,
    scaleFactor=1.1,      # detection sensitivity (1.05–1.2 এর মধ্যে ভাল কাজ করে)
    minNeighbors=5,        # false detection কমানোর জন্য ৫–৬ ভালো মান
    minSize=(50, 50),      # ছোট মুখ বাদ দেবে
    maxSize=(300, 300)     # বড় মুখ বাদ দেবে
)

# 5️⃣ সনাক্ত মুখের চারপাশে rectangle আঁকা
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)

# 6️⃣ ফলাফল দেখানো
cv2.imshow('Haar Cascade - Face Detection (Image)', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![Screenshot from 2025-10-25 16-52-51.png](attachment:37a09e23-c131-4797-8211-e99504788352.png)

# %% [markdown]
# ## 2. Face Detection (Video File)

# %%
import cv2

# 1️⃣ Haar Cascade লোড করা
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# 2️⃣ ভিডিও ফাইল লোড করা
video_path = "../dataset/vid/s.mp4"  # 👉 আপনার ভিডিও ফাইলের path দিন
cap = cv2.VideoCapture(video_path)

# 3️⃣ ভিডিও ফ্রেম ধরে ধরে পড়া
while True:
    ret, frame = cap.read()
    if not ret:
        break  # ভিডিও শেষ হলে বেরিয়ে আসবে

    # 4️⃣ প্রতিটি ফ্রেমকে grayscale এ রূপান্তর
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # 5️⃣ মুখ সনাক্তকরণ
    faces = face_cascade.detectMultiScale(
        gray,
        scaleFactor=1.1,      # detection sensitivity
        minNeighbors=5,        # false detection কমাতে
        minSize=(50, 50),      # ছোট মুখ বাদ দিতে
        maxSize=(300, 300)     # বড় মুখ বাদ দিতে
    )

    # 6️⃣ সনাক্ত মুখের চারপাশে rectangle আঁকা
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)

    # 7️⃣ ফ্রেম show করা
    cv2.imshow("Haar Cascade - Face Detection (Video)", frame)

    # 8️⃣ 'q' চাপলে ভিডিও বন্ধ হবে
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# 9️⃣ সব রিসোর্স রিলিজ করা
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ![Screenshot from 2025-10-25 16-54-39.png](attachment:b7291b59-3a2c-4aa8-bedb-5d09b4ac08b4.png)

# %% [markdown]
# ## 3. Webcam Real-Time Face Detection

# %%
import cv2

# 1️⃣ Haar Cascade লোড
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# 2️⃣ Webcam Capture
cap = cv2.VideoCapture(0)  # 0 → default webcam

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # 3️⃣ Grayscale conversion
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # 4️⃣ Face Detection with parameters
    faces = face_cascade.detectMultiScale(
        gray,
        scaleFactor=1.1,      # detection sensitivity
        minNeighbors=5,        # quality control
        minSize=(50, 50),      # ignore very small faces
        maxSize=(300, 300)     # ignore very large faces
    )

    # 5️⃣ Draw rectangle around faces
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)

    # 6️⃣ Show frame
    cv2.imshow('Webcam Face Detection', frame)

    # 7️⃣ Quit on 'q' key
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# 8️⃣ Release resources
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ![Screenshot from 2025-10-25 16-49-31.png](attachment:a62c7bf1-8f74-48d2-b5e9-8405fdfb8486.png)
