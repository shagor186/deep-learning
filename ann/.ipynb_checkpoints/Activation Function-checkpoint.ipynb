# %% [markdown]
# ![Screenshot from 2025-10-18 08-50-52.png](attachment:36aa95f8-a898-41e4-98bb-2321d471da87.png)

# %% [markdown]
# ![Screenshot from 2025-10-18 08-53-27.png](attachment:45fb60bb-82bc-4f9a-861d-3af0ba68cd09.png)

# %% [markdown]
# ![Screenshot from 2025-10-18 08-52-07.png](attachment:1eaedf3e-afc4-4255-8607-cbb9c11d5f40.png)

# %% [markdown]
# ![Screenshot from 2025-10-18 08-54-40.png](attachment:d7a373da-0b13-497b-8815-f8ac2a1d4220.png)

# %% [markdown]
# # 1. Step Function

# %% [markdown]
# ![Screenshot from 2025-10-18 08-57-46.png](attachment:587a9e2f-c30f-4755-bd0f-471636544566.png)

# %% [markdown]
# ![Screenshot from 2025-10-18 08-58-32.png](attachment:27f2f06a-fe1c-4150-9897-9cedacc52c4e.png)

# %% [markdown]
# ![Screenshot from 2025-10-18 08-59-25.png](attachment:a5dfa695-80c3-4a22-88ba-34a3f789d6b0.png)

# %% [markdown]
# ![image.png](attachment:68cf8d61-fd55-46d3-b1a9-03ce7d276ce5.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Step function সংজ্ঞা
def step_function(x):
    return np.where(x >= 0, 1, 0)

# ইনপুট ডাটা তৈরি
x = np.linspace(-5, 5, 100)
y = step_function(x)

# গ্রাফ আঁকা
plt.plot(x, y)
plt.title("Step Activation Function")
plt.xlabel("Input (x)")
plt.ylabel("Output f(x)")
plt.grid(True)
plt.show()

# %% [markdown]
# **Output:**
# * একটি স্টেপ আকৃতির গ্রাফ — যেখানে x<0 তে মান 0 এবং x≥0 তে মান 1।

# %% [markdown]
# **TensorFlow ANN Architecture**

# %% [markdown]
# TensorFlow এ সরাসরি Step Function নেই, তাই আমরা custom activation বানাবো।

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np

# Differentiable Step Function approximation
@tf.function
def approx_step(x):
    return tf.sigmoid(10.0 * x)  # 10 makes it steep like a Step

# ANN Model
model = keras.Sequential([
    layers.Dense(1, input_shape=(1,), activation=approx_step)
])

# Compile model
model.compile(optimizer='sgd', loss='mean_squared_error')

# Training data
x_train = np.array([-2.0, -1.0, 0.0, 1.0, 2.0])
y_train = np.array([0.0, 0.0, 1.0, 1.0, 1.0])

# Train model
model.fit(x_train, y_train, epochs=1000, verbose=0)

# Predictions
preds = model.predict(x_train).flatten()
print("Predictions:", preds)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Predictions: [1.4036362e-10 5.9497146e-05 9.6186489e-01 9.9999988e-01 1.0000000e+00]

# %% [markdown]
# ![Screenshot from 2025-10-18 09-07-31.png](attachment:ed43570d-7f94-4bda-81d4-96c5e0d0e8ea.png)

# %% [markdown]
# ![Screenshot from 2025-10-18 09-08-16.png](attachment:0c1c9f82-e441-4bab-9b66-123610a07275.png)

# %% [markdown]
# # 2. Linear (Identity) Activation Function

# %% [markdown]
# ![Screenshot from 2025-10-18 09-16-32.png](attachment:c5474bef-0cae-440a-8357-9f8061ab2274.png)

# %% [markdown]
# ![Screenshot from 2025-10-18 09-17-15.png](attachment:e30c9797-e3bf-4d36-8c64-74a392e98380.png)

# %% [markdown]
# ![Screenshot from 2025-10-18 09-17-38.png](attachment:fd046a72-31ca-46a8-a3b2-0cd99fbb3d5c.png)

# %% [markdown]
# ![image.png](attachment:bb9327e5-3fe9-4c67-8a52-8679e78933ef.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

def linear_function(x):
    return x  # বা 1*x

x = np.linspace(-5, 5, 100)
y = linear_function(x)

plt.plot(x, y, color='blue')
plt.title("Linear (Identity) Activation Function")
plt.xlabel("Input (x)")
plt.ylabel("Output f(x)")
plt.grid(True)
plt.show()

# %% [markdown]
# **Output:**
# * একটি diagonal সোজা রেখা (x=y) দেখা যাবে।

# %% [markdown]
# **TensorFlow ANN Architecture**
#
# * Linear Activation সাধারণত Output Layer (Regression Task)-এ ব্যবহৃত হয়।
# * চলো একটি ছোট ANN Regression Example দেখি

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np

# Linear Activation Function (Identity)
def linear_activation(x):
    return x

# ANN Model
model = keras.Sequential([
    layers.Dense(8, input_shape=(1,), activation='relu'),
    layers.Dense(1, activation=linear_activation)  # output layer = linear
])

# Compile model (Regression)
model.compile(optimizer='adam', loss='mse')

# Sample training data (simple y = 2x + 1)
x_train = np.array([-3., -2., -1., 0., 1., 2., 3.])
y_train = 2*x_train + 1

# Train model
model.fit(x_train, y_train, epochs=200, verbose=0)

# Predict
pred = model.predict(x_train).flatten()
print("Predicted:", np.round(pred, 2))
print("Actual:   ", y_train)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Predicted: [-3.55 -2.4  -1.24 -0.08  0.17  0.1   0.04]
# Actual:    [-5. -3. -1.  1.  3.  5.  7.]

# %% [markdown]
# * দেখা যাচ্ছে — মডেলটি ইনপুট-আউটপুটের linear সম্পর্ক সুন্দরভাবে শিখছে।

# %% [markdown]
# ![Screenshot from 2025-10-18 09-22-12.png](attachment:a2f1182d-9fd3-4fec-93f5-db587b3f3ffe.png)

# %% [markdown]
# ![Screenshot from 2025-10-18 09-22-42.png](attachment:b5b54465-2085-475d-9f20-9f2c1b16d052.png)

# %% [markdown]
# # 3. Sigmoid Activation Function

# %% [markdown]
# ![Screenshot from 2025-10-18 10-41-34.png](attachment:241aded9-1c58-4067-9862-5f778a369a9e.png)

# %% [markdown]
# ![Screenshot from 2025-10-18 10-43-47.png](attachment:1709c293-f6ab-43ae-8d22-5fea962771b9.png)

# %% [markdown]
# ![Screenshot from 2025-10-18 10-44-17.png](attachment:4273c21b-a007-4f8a-8453-dbf506ececbe.png)

# %% [markdown]
# ![image.png](attachment:1573099b-722a-4e66-8e44-a5c63ddee607.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

x = np.linspace(-10, 10, 100)
y = sigmoid(x)

plt.plot(x, y)
plt.title("Sigmoid Activation Function")
plt.xlabel("Input (x)")
plt.ylabel("Output f(x)")
plt.grid(True)
plt.show()

# %% [markdown]
# **Output:** S-shaped curve দেখা যাবে।

# %% [markdown]
# **TensorFlow ANN Example**
# * Sigmoid Function ANN এ hidden layer বা output layer এ ব্যবহার করা যায়।
# * Binary Classification উদাহরণ:

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np

# Sample binary classification data
x_train = np.array([[-2], [-1], [0], [1], [2]])
y_train = np.array([[0], [0], [0], [1], [1]])  # binary labels

# ANN Model
model = keras.Sequential([
    layers.Dense(4, input_shape=(1,), activation='sigmoid'),  # hidden layer
    layers.Dense(1, activation='sigmoid')                    # output layer
])

# Compile model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train model
model.fit(x_train, y_train, epochs=500, verbose=0)

# Predict
pred = model.predict(x_train)
print("Predictions:", np.round(pred.flatten(),2))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Predictions: [0.29 0.34 0.45 0.58 0.66]

# %% [markdown]
# দেখা যাচ্ছে — output probability 0 এবং 1 এর মধ্যে।

# %% [markdown]
# ![Screenshot from 2025-10-18 10-51-49.png](attachment:94f155a8-0820-48d8-ba52-9ec60e35f58d.png)

# %% [markdown]
# # 4. Tanh Activation Function

# %% [markdown]
# ![Screenshot from 2025-10-18 10-59-05.png](attachment:c2cf0e87-bd39-4287-aafa-234c0106d337.png)

# %% [markdown]
# ![Screenshot from 2025-10-18 10-59-35.png](attachment:483f15b3-8686-4f3c-b666-6efe616b85a2.png)

# %% [markdown]
# ![Screenshot from 2025-10-18 11-00-02.png](attachment:cfd50df8-3a2c-41c0-b340-8af926278a9a.png)

# %% [markdown]
# ![image.png](attachment:9baca094-203a-47b6-ae32-343314942df6.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

def tanh(x):
    return np.tanh(x)

x = np.linspace(-5, 5, 100)
y = tanh(x)

plt.plot(x, y, color='purple')
plt.title("Tanh Activation Function")
plt.xlabel("Input (x)")
plt.ylabel("Output f(x)")
plt.grid(True)
plt.show()

# %% [markdown]
# **Output:** S-shaped curve, centered at 0।

# %% [markdown]
# **TensorFlow ANN Example**
# * Tanh সাধারণত hidden layer-এ ব্যবহৃত হয়।
# * Binary classification উদাহরণ:

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np

# Sample data
x_train = np.array([[-2], [-1], [0], [1], [2]])
y_train = np.array([[0], [0], [0], [1], [1]])

# ANN Model with Tanh
model = keras.Sequential([
    layers.Dense(4, input_shape=(1,), activation='tanh'),  # hidden layer
    layers.Dense(1, activation='sigmoid')                  # output layer
])

# Compile model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train
model.fit(x_train, y_train, epochs=500, verbose=0)

# Predict
pred = model.predict(x_train)
print("Predictions:", np.round(pred.flatten(),2))
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x782280e880e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Predictions: [0.06 0.08 0.25 0.75 0.88]

# %% [markdown]
# ![Screenshot from 2025-10-18 11-06-20.png](attachment:1d15cd0b-9c5a-4952-a320-254b20c8901d.png)

# %% [markdown]
# # 5.  ReLU Activation Function

# %% [markdown]
# ![Screenshot from 2025-10-18 11-08-28.png](attachment:7ca0e6ce-be9a-4d7f-88c8-245e6609847e.png)

# %% [markdown]
# ![Screenshot from 2025-10-18 11-08-57.png](attachment:4089fb21-b1b3-4f3e-b016-5573cd6dce66.png)

# %% [markdown]
# ![Screenshot from 2025-10-18 11-11-11.png](attachment:5f572ba0-c91a-49d6-8153-78df569d10bb.png)

# %% [markdown]
# ![image.png](attachment:8746bdfc-ec95-48a7-acd2-1428e172ded4.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

def relu(x):
    return np.maximum(0, x)

x = np.linspace(-5, 5, 100)
y = relu(x)

plt.plot(x, y, color='red')
plt.title("ReLU Activation Function")
plt.xlabel("Input (x)")
plt.ylabel("Output f(x)")
plt.grid(True)
plt.show()

# %% [markdown]
# **Output:** x<0 হলে 0, x≥0 হলে linear increase

# %% [markdown]
# **TensorFlow ANN Example**
# * ReLU hidden layer এ সবচেয়ে বেশি ব্যবহৃত হয়।

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np

# Sample data
x_train = np.array([[-2], [-1], [0], [1], [2]])
y_train = np.array([[0], [0], [0], [1], [1]])

# ANN Model with ReLU
model = keras.Sequential([
    layers.Dense(4, input_shape=(1,), activation='relu'),  # hidden layer
    layers.Dense(1, activation='sigmoid')                 # output layer
])

# Compile model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train model
model.fit(x_train, y_train, epochs=500, verbose=0)

# Predict
pred = model.predict(x_train)
print("Predictions:", np.round(pred.flatten(),2))
# Out:
# /home/shagor/Desktop/code/deep learning/env_dl/lib/python3.12/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ...

# %% [markdown]
# দেখা যাচ্ছে — negative input → 0, positive input → output probability build হচ্ছে।

# %% [markdown]
# ![Screenshot from 2025-10-18 11-11-56.png](attachment:4f995731-a14e-47a9-b240-13468f0ae5eb.png)

# %% [markdown]
# # 6. Leaky ReLU Activation Function

# %% [markdown]
# ![Screenshot from 2025-10-18 11-16-28.png](attachment:ecb0e718-775b-45a5-9a02-3d8e7d44bcd4.png)

# %% [markdown]
# ![Screenshot from 2025-10-18 11-16-56.png](attachment:af607d78-7329-44fc-8a71-79527852bf59.png)

# %% [markdown]
# ![Screenshot from 2025-10-18 11-19-04.png](attachment:2c8a912c-ed6e-49d6-875b-87d2d12e0172.png)

# %% [markdown]
# ![image.png](attachment:de964e3c-c506-4b9a-9a7a-7ef0575044a7.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

def leaky_relu(x, alpha=0.01):
    return np.where(x >= 0, x, alpha * x)

x = np.linspace(-5, 5, 100)
y = leaky_relu(x)

plt.plot(x, y, color='green')
plt.title("Leaky ReLU Activation Function")
plt.xlabel("Input (x)")
plt.ylabel("Output f(x)")
plt.grid(True)
plt.show()

# %% [markdown]
# **Output:** x<0 হলে tiny negative slope, x≥0 linear increase

# %% [markdown]
# **TensorFlow ANN Example**

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np

# Sample data
x_train = np.array([[-2], [-1], [0], [1], [2]])
y_train = np.array([[0], [0], [0], [1], [1]])

# ANN Model with Leaky ReLU
model = keras.Sequential([
    layers.Dense(4, input_shape=(1,), activation=tf.keras.layers.LeakyReLU(alpha=0.01)),  # hidden layer
    layers.Dense(1, activation='sigmoid')                                                # output layer
])

# Compile model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train
model.fit(x_train, y_train, epochs=500, verbose=0)

# Predict
pred = model.predict(x_train)
print("Predictions:", np.round(pred.flatten(),2))
# Out:
# /home/shagor/Desktop/code/deep learning/env_dl/lib/python3.12/site-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# /home/shagor/Desktop/code/deep learning/env_dl/lib/python3.12/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Predictions: [0.13 0.2  0.4  0.73 0.88]

# %% [markdown]
# দেখা যাচ্ছে, negative input এ neuron dead হয়নি, output tiny negative value দিয়ে learning চালু থাকে।

# %% [markdown]
# ![Screenshot from 2025-10-18 11-22-51.png](attachment:1f5992ec-fb12-4660-a8fc-0d647d14123c.png)

# %% [markdown]
# # 7. Parametric ReLU (PReLU) Activation Function

# %% [markdown]
# ![Screenshot from 2025-10-18 11-25-22.png](attachment:287af088-3f67-4c11-8bec-f6e95e7cf85b.png)

# %% [markdown]
# ধরে নিই α=0.1 (এখানে শুধু প্রদর্শনের জন্য):

# %% [markdown]
# ![image.png](attachment:8402bd95-7103-4bb9-8aaf-a323ce5c57dc.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

def prelu(x, alpha=0.1):
    return np.where(x >= 0, x, alpha * x)

x = np.linspace(-5, 5, 100)
y = prelu(x)

plt.plot(x, y, color='orange')
plt.title("PReLU Activation Function (α=0.1)")
plt.xlabel("Input (x)")
plt.ylabel("Output f(x)")
plt.grid(True)
plt.show()

# %% [markdown]
# **Output:** x≥0 linear, x<0 tiny slope α দিয়ে linear

# %% [markdown]
# **TensorFlow ANN Example (Learnable α)**

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np

# Sample data
x_train = np.array([[-2], [-1], [0], [1], [2]])
y_train = np.array([[0], [0], [0], [1], [1]])

# ANN Model with PReLU
model = keras.Sequential([
    layers.Dense(4, input_shape=(1,)),
    layers.PReLU(),                 # learnable α
    layers.Dense(1, activation='sigmoid')
])

# Compile model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train
model.fit(x_train, y_train, epochs=500, verbose=0)

# Predict
pred = model.predict(x_train)
print("Predictions:", np.round(pred.flatten(),2))
# Out:
# /home/shagor/Desktop/code/deep learning/env_dl/lib/python3.12/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Predictions: [0.03 0.09 0.27 0.82 0.97]

# %% [markdown]
# দেখা যাচ্ছে — model নিজে negative slope α শিখেছে এবং neuron dead হয়নি।

# %% [markdown]
# ![Screenshot from 2025-10-18 11-29-43.png](attachment:60504a99-6a83-4882-a24a-0b10ed3938e0.png)

# %% [markdown]
# # 8. Softmax Activation Function

# %% [markdown]
# ![Screenshot from 2025-10-18 11-31-13.png](attachment:94aed161-b376-4ca5-837e-4bcb3e955972.png)

# %% [markdown]
# ![Screenshot from 2025-10-18 11-32-15.png](attachment:be58795d-1271-4b8a-8adf-cb896ea3e2cc.png)

# %% [markdown]
# ![image.png](attachment:47e9bf94-5530-4fc9-95a3-8cc1ed1e4039.png)

# %%
import numpy as np

def softmax(z):
    exp_z = np.exp(z - np.max(z))  # numerical stability
    return exp_z / np.sum(exp_z)

z = np.array([2.0, 1.0, 0.0])
probabilities = softmax(z)
print("Softmax probabilities:", np.round(probabilities,3))
print("Sum:", np.sum(probabilities))
# Out:
# Softmax probabilities: [0.665 0.245 0.09 ]
# Sum: 1.0000000000000002

# %% [markdown]
# সব probability 0–1 এবং sum = 1

# %% [markdown]
# **TensorFlow ANN Example**

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np

# Sample multi-class data
x_train = np.array([[0.1], [0.5], [0.9]])
y_train = np.array([[1,0,0], [0,1,0], [0,0,1]])  # one-hot labels

# ANN Model with Softmax output
model = keras.Sequential([
    layers.Dense(4, input_shape=(1,), activation='relu'),
    layers.Dense(3, activation='softmax')  # output layer = softmax
])

# Compile model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train model
model.fit(x_train, y_train, epochs=500, verbose=0)

# Predict
pred = model.predict(x_train)
print("Predictions:\n", np.round(pred,3))
# Out:
# /home/shagor/Desktop/code/deep learning/env_dl/lib/python3.12/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Predictions:
#  [[0.324 0.344 0.332]
#  [0.324 0.344 0.332]
#  [0.354 0.307 0.339]]

# %% [markdown]
# দেখা যাচ্ছে — model প্রতিটি input এর জন্য class probability output করছে।

# %% [markdown]
# ![Screenshot from 2025-10-18 11-34-54.png](attachment:c30c6b00-ecb9-4641-9bd9-39a4925a0fdd.png)
