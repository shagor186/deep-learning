# %% [markdown]
# ![Screenshot from 2025-10-21 07-23-34.png](attachment:77f00bd4-887f-4579-b272-b9e5ac59ffd1.png)

# %% [markdown]
# ![Screenshot from 2025-10-21 07-25-25.png](attachment:567fdcec-6f9a-4213-8918-fc31e78a25b4.png)
#
# **`Input Image → Convolution → ReLU → Pooling → Convolution → ReLU → Pooling → Flatten → Dense → Output`**
#
# চলো প্রতিটি অংশ গভীরভাবে বুঝি ⤵️

# %% [markdown]
# ![Screenshot from 2025-10-21 07-27-57.png](attachment:590c833b-3a76-45a6-b821-4f86b8b787a7.png)

# %% [markdown]
# ![Screenshot from 2025-10-21 07-28-30.png](attachment:8ce0a0fd-1c5b-4344-887c-b7849148d6fe.png)

# %% [markdown]
# ![Screenshot from 2025-10-21 07-29-03.png](attachment:838c5e87-f2c6-44d5-b7ca-e6e212fcfd26.png)

# %% [markdown]
# ![Screenshot from 2025-10-21 07-29-57.png](attachment:bbd757df-940d-4c6e-9dd5-fed5beebd662.png)

# %% [markdown]
# ![Screenshot from 2025-10-21 07-30-26.png](attachment:290aa600-5860-4822-ad7f-96e8f75611cd.png)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

model = models.Sequential([
    # 1️⃣ প্রথম Convolution + Pooling
    layers.Conv2D(32, (3,3), activation='relu', input_shape=(64, 64, 3)),
    layers.MaxPooling2D((2,2)),

    # 2️⃣ দ্বিতীয় Convolution + Pooling
    layers.Conv2D(64, (3,3), activation='relu'),
    layers.MaxPooling2D((2,2)),

    # 3️⃣ Flatten + Dense Layers
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')  # 10 ক্লাস ধরে নেওয়া
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# 2025-10-21 07:31:47.226178: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-21 07:31:47.232174: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-10-21 07:31:47.295848: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-10-21 07:31:47.348537: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %% [markdown]
# ![Screenshot from 2025-10-21 07-32-28.png](attachment:f39b412f-f3ca-4935-92e5-cf3a07fddcb3.png)

# %% [markdown]
# ![Screenshot from 2025-10-21 07-32-55.png](attachment:5e2c5971-4c8d-43ed-bf61-df9c786314b0.png)
