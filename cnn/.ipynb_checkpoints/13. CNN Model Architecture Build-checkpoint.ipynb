# %% [markdown]
# ![Screenshot from 2025-10-23 11-40-48.png](attachment:9fa4e03f-4ccd-4bfa-bdce-a47d33616ec0.png)

# %% [markdown]
# ![Screenshot from 2025-10-23 11-41-28.png](attachment:93dd84c8-d05a-448b-a3a0-bbe6a14698f1.png)

# %% [markdown]
# ![Screenshot from 2025-10-23 11-42-56.png](attachment:62d3eed9-d5f4-46f7-98e6-48dfcc6c055a.png)

# %% [markdown]
# ![Screenshot from 2025-10-23 11-43-49.png](attachment:8fde3e1d-bffe-43b3-84d1-cc78ae241339.png)

# %% [markdown]
# ![Screenshot from 2025-10-23 11-47-55.png](attachment:408abaac-4a52-4c7e-88f8-3df29cc6b010.png)

# %% [markdown]
# ![Screenshot from 2025-10-23 11-44-14.png](attachment:27026960-4a93-40a3-b936-cc551644f899.png)

# %% [markdown]
# ![Screenshot from 2025-10-23 11-48-30.png](attachment:a93f3f74-a01f-462c-a1ca-37f4464b0e01.png)

# %% [markdown]
# ![Screenshot from 2025-10-23 11-44-42.png](attachment:29674816-586c-46eb-8684-bee4ce7900ca.png)

# %% [markdown]
# ![Screenshot from 2025-10-23 11-49-11.png](attachment:b72c36b7-4dd5-4a03-acac-8d39d28d45b2.png)

# %% [markdown]
# ![Screenshot from 2025-10-23 11-45-11.png](attachment:33be1527-f5a2-4092-b06b-175f56cc82d0.png)

# %% [markdown]
# ![Screenshot from 2025-10-23 11-49-48.png](attachment:8c2038fe-1b3b-4607-a06b-5c37b90fa653.png)

# %% [markdown]
# ![Screenshot from 2025-10-23 11-45-38.png](attachment:73942ff1-e421-418e-b0dc-7238543316c9.png)

# %% [markdown]
# ![Screenshot from 2025-10-23 11-50-22.png](attachment:d36ed9ca-73b8-43c4-9b85-458fdd9a37c5.png)

# %% [markdown]
# ![Screenshot from 2025-10-23 11-46-03.png](attachment:ae1fc709-0192-47d5-8ec5-e5fce341cb05.png)

# %% [markdown]
# ![Screenshot from 2025-10-23 11-50-53.png](attachment:eb554ba4-4299-422b-8d28-b3b851fdfd2c.png)

# %% [markdown]
# ![Screenshot from 2025-10-23 11-46-33.png](attachment:53bb3706-2d95-426d-9aa6-054468e50099.png)

# %% [markdown]
# ![Screenshot from 2025-10-23 11-51-19.png](attachment:f68005f9-f8a9-4d75-b406-38fafd9001ec.png)

# %% [markdown]
# ![Screenshot from 2025-10-23 11-47-02.png](attachment:a9021f23-2302-4d8c-8c44-1c0ee8b2ce76.png)

# %% [markdown]
# ![Screenshot from 2025-10-23 11-51-54.png](attachment:351b67d6-66a7-4aae-b5f3-4417dbdca34d.png)

# %% [markdown]
# **Full CNN Example (MNIST)**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense

model = Sequential()

# Conv + ReLU
model.add(Conv2D(32, (3,3), activation='relu', input_shape=(28,28,1)))
# Pooling
model.add(MaxPooling2D(pool_size=(2,2)))
# Dropout
model.add(Dropout(0.25))

# Conv + ReLU
model.add(Conv2D(64, (3,3), activation='relu'))
# Pooling
model.add(MaxPooling2D(pool_size=(2,2)))
# Dropout
model.add(Dropout(0.25))

# Flatten
model.add(Flatten())

# Dense Hidden
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))

# Output Layer
model.add(Dense(10, activation='softmax'))

# Model summary
model.summary()
# Out:
# 2025-10-23 11:54:55.066354: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-23 11:54:55.066754: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-10-23 11:54:55.069373: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-10-23 11:54:55.076697: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %% [markdown]
# ![Screenshot from 2025-10-23 11-55-13.png](attachment:2f16ee93-f82e-473e-b9f9-40fc3f5d2253.png)

# %% [markdown]
# ![Screenshot from 2025-10-23 11-55-40.png](attachment:d6e3ef83-05f4-4dbe-8d78-17e62a451ef7.png)

# %% [markdown]
# ![Screenshot from 2025-10-23 11-56-05.png](attachment:ca228e60-c719-4ff0-9723-b90e0230edeb.png)
